# %%
x = "tiger"
y = ""
while y!=x:
 y = input("Your Guess is wrong enter it again:")
print("You Guessed it right! You wind")
# Out:
# Your Guess is wrong enter it again:dghbdh
# Your Guess is wrong enter it again:dfgdf
# Your Guess is wrong enter it again:dfgdf
# Your Guess is wrong enter it again:tiger
# You Guessed it right! You win

# %%
x = "tiger"
y = ""
guess_counter = 0
guess_limit = 3
while y!=x and guess_counter<3:
  y = input("Your Guess is wrong enter it again:")
  guess_counter=guess_counter+1
  print(guess_counter)
  if guess_limit==guess_counter:
    print("You Have exhausted the limit!")
if y==x:
  print("You Win!")
# Out:
# Your Guess is wrong enter it again:u
# 1
# Your Guess is wrong enter it again:tiger
# 2
# You Win!
