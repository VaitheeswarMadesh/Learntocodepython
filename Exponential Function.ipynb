# %%
def exponen(a,b):
  c=a**b
  print(c)
exponen(2,4)
# Out:
# 16

# %%
print(2**4)
# Out:
# 16

# %%
def exp(a,b):
  result = 1
  for i in range(b):
    result = result*a
  print(result)
exp(2,3)
# Out:
# 4

# %%
def exp(a,b):
  result = 1
  for i in range(b):
    result = result*a
    print(result)
exp(2,4)
# Out:
# 2
# 4
# 8
# 16
