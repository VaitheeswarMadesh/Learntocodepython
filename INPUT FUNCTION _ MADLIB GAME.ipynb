# %% [markdown]
# input() Function in python takes the input from the user and processes it. Arguments have to be given within the Paranthesis.
#
# ---

# %%
Name = input("Hello What is your name:")
print("You Just said your Name as:" +Name)
print("Hi," +Name + "!")
# Out:
# Hello What is your name:Hafeezuddin Shaik
# You Just said your Name as:Hafeezuddin Shaik
# Hi,Hafeezuddin Shaik!

# %%
#SAMPLE MADLIBS GAMES

color = input("Please enter the color:")
noun = input("Enter any noun:")
celebrity = input("Enter the celebrity Name:")

print("ROSES ARE " +color)
print("Voilets are " +noun)
print("I Love " +celebrity)
# Out:
# Please enter the color:yellow
# Enter any noun:green
# Enter the celebrity Name:alia
# ROSES ARE yellow
# Voilets are green
# I Love alia
