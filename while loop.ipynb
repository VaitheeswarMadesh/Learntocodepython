# %% [markdown]
# WHILE LOOPS EXECUTE SPECIFIC LINES OF CODE TILL THE CONDITION IS FAILED

# %%
x=1
while x<=4:  #This is a condition.  #intendation is mandatory.
  print("Hello")    #total 4 iterations as x=1 and condition is x<=4
  print(x)
  x=x+1
print("done with loop")
# Out:
# Hello
# 1
# Hello
# 2
# Hello
# 3
# Hello
# 4
# done with loop
