# %% [markdown]
# COMMENTS ARE STARTED WITH #
#
# IT IS BASCIALLY USE FOR UNDERSTANFING THE CODE BY DEVELOPER
#
# INTREPRETER SKIPS THE LEAR

# %%
  #THIS PROGRAM IS COOL
  #THIS IS A COMMENT DEMONSTRATION

  print("HI")
  #The above program prints HI
# Out:
# HI

# %%
'''
Even this is comment

print("hello user")
